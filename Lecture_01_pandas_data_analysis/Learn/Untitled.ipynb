# %%
import pandas as pd
import numpy as np

# %%
telecom_df = pd.read_csv('telecom_churn.csv')

# %%
pd.set_option('display.max_columns',100)
pd.set_option('display.max_rows', 100)

# %%
telecom_df
# Out:
#      State  Account length  Area code International plan Voice mail plan  \
# 0       KS             128        415                 No             Yes
# 1       OH             107        415                 No             Yes
# 2       NJ             137        415                 No              No
# 3       OH              84        408                Yes              No
# 4       OK              75        415                Yes              No
# 5       AL             118        510                Yes              No
# 6       MA             121        510                 No             Yes
# 7       MO             147        415                Yes              No
# 8       LA             117        408                 No              No
# 9       WV             141        415                Yes             Yes
# 10      IN              65        415                 No              No
# 11      RI              74        415                 No              No
# ...

# %%
# describe dataframe options
pd.describe_option()
# Out:
# compute.use_bottleneck : bool
#     Use the bottleneck library to accelerate if it is installed,
#     the default is True
#     Valid values: False,True
#     [default: True] [currently: True]
#
# compute.use_numexpr : bool
#     Use the numexpr library to accelerate computation if it is installed,
#     the default is True
#     Valid values: False,True
#     [default: True] [currently: True]
#
# display.chop_threshold : float or None
#     if set to a float value, all float values smaller then the given threshold
#     will be displayed as exactly 0 by repr and friends.
#     [default: None] [currently: None]
#
# display.colheader_justify : 'left'/'right'
#     Controls the justification of column headers. used by DataFrameFormatter.
#     [default: right] [currently: right]
#
# display.column_space No description available.
#     [default: 12] [currently: 12]
#
# display.date_dayfirst : boolean
#     When True, prints and parses dates with the day first, eg 20/01/2005
# ...

# %%
telecom_df.head(n=20)
# Out:
#    State  Account length  Area code International plan Voice mail plan  \
# 0     KS             128        415                 No             Yes
# 1     OH             107        415                 No             Yes
# 2     NJ             137        415                 No              No
# 3     OH              84        408                Yes              No
# 4     OK              75        415                Yes              No
# 5     AL             118        510                Yes              No
# 6     MA             121        510                 No             Yes
# 7     MO             147        415                Yes              No
# 8     LA             117        408                 No              No
# 9     WV             141        415                Yes             Yes
# 10    IN              65        415                 No              No
# 11    RI              74        415                 No              No
# ...

# %%
telecom_df.shape
# Out:
# (3333, 20)

# %%
print (type(telecom_df.columns))
# Out:
# <class 'pandas.core.indexes.base.Index'>

# %%
telecom_df.columns
# Out:
# Index(['State', 'Account length', 'Area code', 'International plan',
#        'Voice mail plan', 'Number vmail messages', 'Total day minutes',
#        'Total day calls', 'Total day charge', 'Total eve minutes',
#        'Total eve calls', 'Total eve charge', 'Total night minutes',
#        'Total night calls', 'Total night charge', 'Total intl minutes',
#        'Total intl calls', 'Total intl charge', 'Customer service calls',
#        'Churn'],
#       dtype='object')

# %%
indexes = telecom_df.index.get_values()

# %%
print (type(indexes))
# Out:
# <class 'numpy.ndarray'>

# %%
telecom_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3333 entries, 0 to 3332
# Data columns (total 20 columns):
# State                     3333 non-null object
# Account length            3333 non-null int64
# Area code                 3333 non-null int64
# International plan        3333 non-null object
# Voice mail plan           3333 non-null object
# Number vmail messages     3333 non-null int64
# Total day minutes         3333 non-null float64
# Total day calls           3333 non-null int64
# Total day charge          3333 non-null float64
# Total eve minutes         3333 non-null float64
# Total eve calls           3333 non-null int64
# Total eve charge          3333 non-null float64
# Total night minutes       3333 non-null float64
# Total night calls         3333 non-null int64
# Total night charge        3333 non-null float64
# Total intl minutes        3333 non-null float64
# Total intl calls          3333 non-null int64
# Total intl charge         3333 non-null float64
# ...

# %%
telecom_df['Churn'] = telecom_df['Churn'].astype('int')

# %%
describe = telecom_df.describe()

# %%
print(type(describe))
# Out:
# <class 'pandas.core.frame.DataFrame'>

# %%
print ("{0:.2f} %".format(describe.loc['mean','Churn']*100))
# Out:
# 14.49 %

# %%
telecom_df.describe()
# Out:
#        Account length    Area code  Number vmail messages  Total day minutes  \
# count     3333.000000  3333.000000            3333.000000        3333.000000
# mean       101.064806   437.182418               8.099010         179.775098
# std         39.822106    42.371290              13.688365          54.467389
# min          1.000000   408.000000               0.000000           0.000000
# 25%         74.000000   408.000000               0.000000         143.700000
# 50%        101.000000   415.000000               0.000000         179.400000
# 75%        127.000000   510.000000              20.000000         216.400000
# max        243.000000   510.000000              51.000000         350.800000
#
#        Total day calls  Total day charge  Total eve minutes  Total eve calls  \
# count      3333.000000       3333.000000        3333.000000      3333.000000
# mean        100.435644         30.562307         200.980348       100.114311
# ...

# %%
# return DataFrame
describe_obj = telecom_df.describe(include=['object'])

# %%
print (describe_obj)
# Out:
#        State International plan Voice mail plan
# count   3333               3333            3333
# unique    51                  2               2
# top       WV                 No              No
# freq     106               3010            2411

# %%
describe_obj.loc['unique','State']
# Out:
# 51

# %%
# return Series
telecom_df['Voice mail plan'].value_counts()
# Out:
# No     2411
# Yes     922
# Name: Voice mail plan, dtype: int64

# %%
telecom_df['Voice mail plan'].value_counts()['No']
# Out:
# 2411

# %%
# with normalize
telecom_df['Voice mail plan'].value_counts(normalize = True)
# Out:
# No     0.723372
# Yes    0.276628
# Name: Voice mail plan, dtype: float64

# %%
telecom_df.sort_values(by = ['Customer service calls'], ascending=False)
# Out:
#      State  Account length  Area code International plan Voice mail plan  \
# 542     MN             152        415                Yes             Yes
# 2380    NJ              53        408                 No              No
# 1502    SC              64        510                 No             Yes
# 1912    NH             103        408                 No              No
# 902     HI             149        510                 No              No
# 2979    HI              99        408                 No              No
# 1865    MI             146        408                 No              No
# 1694    VT              99        415                 No              No
# 332     AL              86        415                 No              No
# 2953    GA             136        415                 No              No
# 1831    OH              93        415                 No             Yes
# 3112    AR             115        415                 No              No
# ...

# %%
# какова доля людей нелояльных пользователей в нашем датафрейме?
# Способ 1:
print ("1: {0:.2f}".format(describe.loc['mean','Churn']))
# Способ 2:
print ("2: {0:.2f}".format(telecom_df['Churn'].mean()))
# Out:
# 1: 0.14
# 2: 0.14

# %%
# каковы средние значения числовых признаков среди нелояльных пользователей?
telecom_df[telecom_df['Churn'] == 1].mean()
# Out:
# Account length            102.664596
# Area code                 437.817805
# Number vmail messages       5.115942
# Total day minutes         206.914079
# Total day calls           101.335404
# Total day charge           35.175921
# Total eve minutes         212.410145
# Total eve calls           100.561077
# Total eve charge           18.054969
# Total night minutes       205.231677
# Total night calls         100.399586
# Total night charge          9.235528
# Total intl minutes         10.700000
# Total intl calls            4.163561
# Total intl charge           2.889545
# Customer service calls      2.229814
# Churn                       1.000000
# dtype: float64

# %%
# каковы средние значения числовых признаков среди лояльных пользователей?
telecom_df[telecom_df['Churn'] == 0].mean()
# Out:
# Account length            100.793684
# Area code                 437.074737
# Number vmail messages       8.604561
# Total day minutes         175.175754
# Total day calls           100.283158
# Total day charge           29.780421
# Total eve minutes         199.043298
# Total eve calls           100.038596
# Total eve charge           16.918909
# Total night minutes       200.133193
# Total night calls         100.058246
# Total night charge          9.006074
# Total intl minutes         10.158877
# Total intl calls            4.532982
# Total intl charge           2.743404
# Customer service calls      1.449825
# Churn                       0.000000
# dtype: float64

# %%
# сколько в среднем в течение дня разговаривают по телефону нелояльные пользователи?
telecom_df[telecom_df['Churn'] == 1]['Total day minutes'].mean()
# Out:
# 206.91407867494814

# %%
# Какова максимальная длина международных звонков среди лояльных пользователей (Churn == 0),
# не пользующихся услугой международного роуминга ('International plan' == 'No')?
telecom_df[(telecom_df['Churn']==0) & (telecom_df['International plan']=='No')]['Total intl minutes'].max()
# Out:
# 18.9

# %%
describe.loc['max',:]
# Out:
# Account length            243.00
# Area code                 510.00
# Number vmail messages      51.00
# Total day minutes         350.80
# Total day calls           165.00
# Total day charge           59.64
# Total eve minutes         363.70
# Total eve calls           170.00
# Total eve charge           30.91
# Total night minutes       395.00
# Total night calls         175.00
# Total night charge         17.77
# Total intl minutes         20.00
# Total intl calls           20.00
# Total intl charge           5.40
# Customer service calls      9.00
# Churn                       1.00
# Name: max, dtype: float64

# %%
telecom_df.loc[:,'Total eve minutes':'Total eve calls'].apply(np.max, axis = 1).head()
# Out:
# 0    197.4
# 1    195.5
# 2    121.2
# 3     88.0
# 4    148.3
# dtype: float64

# %%
d ={'Yes':1, 'No':0}
telecom_df['International plan'] = telecom_df['International plan'].map(d)

# %%
telecom_df['Voice mail plan'] = telecom_df['Voice mail plan'].map(d)

# %%
telecom_df.iloc[0,0]
# Out:
# 'KS'
